# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# `What is EBS` : if we create EC2 instance and whatever the storage (memory) is allocated in EC2 instance is called as the EBS Storage
#
#
# Amazon EBS (Amazon Elastic Block Storage) is block storage for Amazon EC2 compute instances - it is similar to hard drives attached to your computers or laptops, but in a virtualized environment.

# %% [markdown]
# `What is Elastic File System (EFS`): it is comman space shared for the different server (kind of hard disk)
# it is command shared hard-driveS#
#
# Amazon EFS (Amazon Elastic File System) provides scalable network file storage for Amazon EC2 cloud computing service users
#
# `S3 : Simple storage service `:
#
# Amazon S3 (Amazon Simple Storage Service) is an object storage designed for storing large numbers of user files and backups.
#
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# S3 : in S3 Bucket we can store the multiple object (different kind of files)
# for storing file in S3 we need create the object
#
#
# while creating bucket we can block the public access
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %%
copy url : is pubic access

genrate policy

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
While giving the public access we need to specify the policy
while creating policy action is the important option which access we need to give the user 


/* :object of file

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)
#
# When same name file stored it will be over write
#
# to avoid that use the versioning
#
# it will create unique object
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
#
# if the file not using frequently based on the archive config ,keep move to low categories storages

# %% [markdown]
# for more check the version.pdf

# %% [markdown]
# # `Management`
#
# ![image.png](attachment:image.png)
#
# - `Lifecycle Rule`

# %% [markdown]
# Use lifecycle rules to define actions you want Amazon S3 to take during an object's lifetime such as transitioning objects to another storage class, archiving them, or deleting them after a specified period of time

# %% [markdown]
# if we are not using this file let's suppose for 30 days we want to delete or backup in other storage class for that management is use.
#
# ![image.png](attachment:image.png)
#
#
# we can choose above option as per needs

# %% [markdown]
# - if i dont use the file for 40,90,300 days we getting move to the low level storage class
#
# and it is low cost storage
#
# ![image.png](attachment:image.png)

# %% [markdown]
# - `Repulication Rule` : copy all the contain of one bucket to another buckets
#
# create destination bucket (create new bucket)
#
#
# then after create the replication rule
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # Creating I am user and  use cli

# %% [markdown]
# upload the file from local M/c to Aws server(S3 bucket) with `cli`
#
# command
#
# `aws configure `
#
# then pass the key and password then you will login as i am user
#
# you can perform the any task with provide permission
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
