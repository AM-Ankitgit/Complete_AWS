# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# elastic   :
# ![image.png](attachment:image.png)
#
# resouces will be automatically adjust and charge

# %% [markdown]
# `EC2` : it is virtual server in cloud
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# what is pubilc ipv4 address : this address through which my server know to world

# %% [markdown]
# we connect ec2 instance using putty
# host_name:ec2-user@ipv4 address (without DNS)
# or
#
#
# ![image.png](attachment:image.png)
#
# we connect throught public DNS (region is mention)
#
#
# ![image-2.png](attachment:image-2.png)
#
#
# ls -lrt : to check the list of files

# %% [markdown]
# on ec2 instance if your application  not open internet the  you have to create in bound rule,
#  and add to your instance  security
#
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %%
# hghksjd

# !git status
# !git branch
# Out:
# Running cells with 'Python 3.12.3' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/usr/bin/python3 -m pip install ipykernel -U --user --force-reinstall'

# %%
# !git add .
# !git commit -m "file updated"
# !git push

# !git add .
# !git commit -m "file updated"
# !git push
# Out:
# [main 566ce0c] file updated
#  1 file changed, 73 insertions(+), 2 deletions(-)
# Enumerating objects: 7, done.
# Counting objects: 100% (7/7), done.
# Delta compression using up to 12 threads
# Compressing objects: 100% (4/4), done.
# Writing objects: 100% (4/4), 1.13 KiB | 145.00 KiB/s, done.
# Total 4 (delta 2), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (2/2), completed with 2 local objects.
# To https://github.com/AM-Ankitgit/Complete_AWS.git
#    13fe9f7..566ce0c  main -> main
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean
# Everything up-to-date

# %%
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %%
gh;lkjhg
