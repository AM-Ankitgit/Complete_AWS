# %% [markdown]
# # What is the serverless computing
#
# it is cloud computing execution model that allocates the machine resource on used basis
#
# developer do not need to manage the configuration machine ,networking and management of the infrastructures
#
# all this thing will manage under aws lambda services
# like it will take care of much ram,cpu,which os

# %% [markdown]
# Aws provide two server less engine
#
# `Lambda : `
#
# - it use when we have single application which file(.py,some java file)
# - it use when do not have the continuos work load
# - and use in intermidate work load when we do not have idea how much capacity we need
#
# eg . if suppose i am or someone  uploading the files in  s3 bucket so
#      i want know to what thing uploaded in my s3 bucket i set trigger using the lambda handler and sent email notification
#
#
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)
#
# ![image-4.png](attachment:image-4.png)
# ![image-5.png](attachment:image-5.png)
#
# attached policy
# ![image-6.png](attachment:image-6.png)
#
#
# ![image-7.png](attachment:image-7.png)
#
# `forgate:`
#
# it use to run your dockerized application (to run containers)

# %%
# To send the notification when upload the file in s3
# paste or attached this code to your lambda function


import json 
import urllib.parse
import boto3

s3 = boto3.client('s3')
simple_email_service = boto3.client('ses')

def lambda_handler(event,context):
    bucket = event['Records'][0]['s3']['bucket']['name']
    key = urllib.parse.unquote_plus(event['Records'][0]['s3']['object']['key'],encoding='utf-8')

    try:
        response = s3.get_object(Bucket = bucket,Key=key)

        subject = "File Uploaded From AWS"
        body =  " Hey Dear , hope so got the notification of file uploaded in your s3 bucket"

        message = {"Subject":{"Data":subject},"Body":{"Html":{"Data":body}}}
        res = simple_email_service.send_email(
            Source="priyansh66@gmail.com",
            Destination = {"ToAddresses":["priyansh66@gmail.com"]},
            Message=message
        )
        response['ContentType']

    except Exception as e:
        print(e)
