# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Athena :
#
# -  we perform the query on data using athena to access data stored in s3 using Standard SQL
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # Glue :
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# eg . if your data in s3 bucket and your want to perform the one hot encoding the data we can do by glue creating  transformer
#
# we need to set the job
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## what is  CRAWLER:

# %% [markdown]
# means it create schema of a your data stored in s3
# we say it understand the underline schema of a data
#
# ![image.png](attachment:image.png)
