# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Data warehouse Vs OLTP Vs DataLake

# %% [markdown]
# `OLTP :` here we can used `RDS / Aurora `
#
#  example of OLTP (online transaction process):
#
# here the data access needed daily so this kind of data should store in OLTP platform
#
# ![image.png](attachment:image.png)

# %% [markdown]
# `Data warehouse : ` here we can use `Redshift`
#
# eg . keep the historical data of the customers
#
#
# if you  need the access of is data once or two may be less number of time then we keep the data in warehouse
#
# or your data stored in which may be the processed(clean) (so it can be directly use)

# %% [markdown]
# `Data Lake`: here we can use `S3` services
#
# we just dump the data in data we are not sure when it will be used
#
#
# here we keep the  all kind of data which may not be processed
# from the different team
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Not only sql:
# Nosql
#
# document db
#
# graph DB
#
#
# all of this not have fixed schema
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # RDS;
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # DynamoDB:
# ![image.png](attachment:image.png)

# %% [markdown]
# add data
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# we can also download
